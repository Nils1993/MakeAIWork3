# %%
# pip3 install labelImg

# %%
import pandas as pd

# %%
path = "../informatie/apple_disease_classification/images_bbox/train/normal_apple/original_117.xml"

# %%
test = pd.read_xml(path)

# %%
display(test)
# Out:
#          folder          filename  \
# 0  normal_apple              None
# 1          None  original_117.jpg
# 2          None              None
# 3          None              None
# 4          None              None
# 5          None              None
# 6          None              None
#
#                                                 path database  width  height  \
# 0                                               None     None    NaN     NaN
# 1                                               None     None    NaN     NaN
# 2  C:\Users\nilsm\workspace\MakeAIWork3\Project 3...     None    NaN     NaN
# 3                                               None  Unknown    NaN     NaN
# 4                                               None     None  154.0   142.0
# 5                                               None     None    NaN     NaN
# 6                                               None     None    NaN     NaN
#
# ...
